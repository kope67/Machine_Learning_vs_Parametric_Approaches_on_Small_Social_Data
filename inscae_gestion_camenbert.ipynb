# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv("C:/Users/USER/Desktop/inscae_jeunes_gestion_excel/critères_pour_candidat_1.csv", header=0,encoding="latin-1",sep=";")
data.head()
# Out:
#      1. Moyen pour poster les offres de candidatures  \
# 0  Sites web spécialisés- Réseaux sociaux- Agence...
# 1             Sites web spécialisés- Réseaux sociaux
# 2             Sites web spécialisés- Réseaux sociaux
# 3  Sites web spécialisés- Agences de recrutement-...
# 4                                    Réseaux sociaux
#
#   2. Nombre moyen de jeunes diplômés en gestion recrutés annuellement  \
# 0                                             6 à 10
# 1                                              0 à 5
# 2                                              0 à 5
# 3                                              0 à 5
# 4                                             6 à 10
#
#            3. Préférences pour des universités  \
# 0   Cela dépend des départements ou des postes
# 1  Oui- nous avons des préférences spécifiques
# 2   Cela dépend des départements ou des postes
# 3   Cela dépend des départements ou des postes
# 4  Oui- nous avons des préférences spécifiques
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   1. Moyen pour poster les offres de candidatures                      214 non-null    object
#  1   2. Nombre moyen de jeunes diplômés en gestion recrutés annuellement  214 non-null    object
#  2   3. Préférences pour des universités                                  214 non-null    object
#  3    préférences spécifiques- précisez.                                  214 non-null    object
#  4   4. Privilége universités étrangères                                  214 non-null    object
#  5   5. Attente principal envers les candidats                            214 non-null    object
#  6   6. Les compétences techniques impératives                            214 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['1. Moyen pour poster les offres de candidatures',
#        '2. Nombre moyen de jeunes diplômés en gestion recrutés annuellement',
#        '3. Préférences pour des universités',
#        ' préférences spécifiques- précisez.',
#        '4. Privilége universités étrangères',
#        '5. Attente principal envers les candidats ',
#        '6. Les compétences techniques impératives ',
#        '7. qualités personnelles ou attitudes indispensables ',
#        '8. Importance de la créativité et l'innovation ',
#        '9.  l'éthique et\ndécision d'embauche',
#        '10.certifications supplémentaires appréciés '],
#       dtype='object')

# %%
data.describe()
# Out:
#        1. Moyen pour poster les offres de candidatures  \
# count                                              214
# unique                                              37
# top                                    Réseaux sociaux
# freq                                                44
#
#        2. Nombre moyen de jeunes diplômés en gestion recrutés annuellement  \
# count                                                 214
# unique                                                  4
# top                                                 0 à 5
# freq                                                  147
#
#                3. Préférences pour des universités  \
# count                                          214
# unique                                           4
# top     Cela dépend des départements ou des postes
# freq                                            92
#
#         préférences spécifiques- précisez.  \
# count                                  214
# ...

# %%
fig, axs = plt.subplots(3, 5, figsize=(20, 10))
axs = axs.ravel()

for i, column in enumerate(data.columns):
    # Comptage des modalités
    counts = data[column].value_counts()
    labels = counts.index
    sizes = counts.values
    
    axs[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    axs[i].set_title(column)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11432\2528485218.py:13: UserWarning: Glyph 146 (\x92) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_11432\2528485218.py:13: UserWarning: Glyph 133 (\x85) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\USER\AppData\Local\Temp\ipykernel_11432\2528485218.py:13: UserWarning: Tight layout not applied. tight_layout cannot make Axes width small enough to accommodate all Axes decorations
#   plt.tight_layout()
# c:\Users\USER\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 146 (\x92) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 133 (\x85) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
