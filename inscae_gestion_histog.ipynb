# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv("C:/Users/user/Desktop/chapitre 5/inscae_jeunes_gestion/les_gestionnaires2_1.csv", header=0,encoding="latin-1",sep=";")
data.head()
# Out:
#         Universite                        Specialisation annee_experience  \
# 0           INSCAE                 Marketing, Management    Plus de 5 ans
# 1            ISCAM                             Marketing          3-5 ans
# 2           INSCAE                             Marketing    Plus de 5 ans
# 3           INSCAE  Comptabilité - Contrôle - Audit/ GRH    Plus de 5 ans
# 4  IAE de Poitiers                 Finance, Comptabilité          1-2 ans
#
#    type_emploi                   secteur_activite  \
# 0  Temps plein  Marketing/Publicité, Distribution
# 1  Temps plein                           Énergie
# 2  Temps plein                     Banque/Finance
# 3  Temps plein                                BPO
# 4  Temps plein                     Environnement
#
#                           competence_professionnelle formation_complement  \
# 0  Communication, Travail d'équipe, Leadership, R...                  Oui
# 1  Communication, Travail d'équipe, Leadership, R...                  Non
# 2  Communication, Travail d'équipe, Leadership, R...                  Oui
# 3  Communication, Résolution de problèmes, Adapta...                  Non
# 4              Résolution de problèmes, Adaptabilité                  Non
#
#    taille_equipe   budget_gere nb_jour_formation_an  nb_projet  \
# 0            280  4.500000e+09                   30         10
# 1             50  4.500000e+08                    0          2
# 2             15  1.000000e+09                  120          3
# 3              0  0.000000e+00                    5          3
# 4              1  0.000000e+00                    0          0
#
#                   salaire                                      source_emploi
# 0  Plus de 3 Millions MGA            Réseaux professionnels (LinkedIn, etc.)
# 1  Plus de 3 Millions MGA            Réseaux professionnels (LinkedIn, etc.)
# 2  Plus de 3 Millions MGA            Réseaux professionnels (LinkedIn, etc.)
# 3  Plus de 3 Millions MGA  Sites d'offres d'emploi en ligne, Reseaux prof...
# 4  Plus de 3 Millions MGA            Réseaux professionnels (LinkedIn, etc.)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Universite                  214 non-null    object
#  1   Specialisation              214 non-null    object
#  2   annee_experience            214 non-null    object
#  3   type_emploi                 214 non-null    object
#  4   secteur_activite            214 non-null    object
#  5   competence_professionnelle  214 non-null    object
#  6   formation_complement        214 non-null    object
#  7   taille_equipe               214 non-null    int64
#  8   budget_gere                 214 non-null    float64
#  9   nb_jour_formation_an        214 non-null    object
#  10  nb_projet                   214 non-null    int64
#  11  salaire                     214 non-null    object
#  12  source_emploi               212 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 21.9+ KB

# %%
data.columns
# Out:
# Index(['Universite', 'Specialisation', 'annee_experience', 'type_emploi',
#        'secteur_activite', 'competence_professionnelle',
#        'formation_complement', 'taille_equipe', 'budget_gere',
#        'nb_jour_formation_an', 'nb_projet', 'salaire', 'source_emploi'],
#       dtype='object')

# %%
data.describe()
# Out:
#        taille_equipe   budget_gere   nb_projet
# count     214.000000  2.140000e+02  214.000000
# mean       55.766355  4.269430e+11    4.042056
# std       254.639267  6.151909e+12    4.640413
# min         0.000000  0.000000e+00    0.000000
# 25%         3.000000  0.000000e+00    2.000000
# 50%         7.500000  4.000000e+07    3.000000
# 75%        18.000000  3.875000e+08    5.000000
# max      2400.000000  9.000000e+13   35.000000

# %%
fig, axs =plt.subplots(3,5,figsize=(20,10))
axs=axs.ravel()
for i, column in enumerate(data.columns):
    axs[i].hist(data[column], bins=50)
    axs[i].set_title(column)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 axs=axs.ravel()
#       3 for i, column in enumerate(data.columns):
# ----> 4     axs[i].hist(data[column], bins=50)
#       5     axs[i].set_title(column)
#       6 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6711, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6709 if orientation == "vertical":
#    6710     convert_units = self.convert_xunits
# -> 6711     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6712          *map(convert_units, x[1:])]
#    6713 else:  # horizontal
#    6714     convert_units = self.convert_yunits
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2551, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if (axis is not None and
#    2549             data is not None and
#    2550             not axis._have_units_and_converter()):
# -> 2551         axis.update_units(data)
#    2552 for axis_name, axis in axis_map.items():
#    2553     # Return if no axis is set.
#    2554     if axis is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\axis.py:1670, in Axis.update_units(self, data)
#    1668 neednew = self.converter != converter
#    1669 self.converter = converter
# -> 1670 default = self.converter.default_units(data, self)
#    1671 if default is not None and self.units is None:
#    1672     self.set_units(default)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File ~\anaconda3\lib\site-packages\matplotlib\category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 146 (\x92) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
